# %%
import pandas as pd
# Load the CSV files
df_experimental = pd.read_csv(r'C:\xampp\htdocs\project_excel_postgresql\products_one.csv')
df_template = pd.read_csv(r'C:\xampp\htdocs\project_excel_postgresql\product_two.csv')
# Display the first few rows of each DataFrame
print("Experimental Sample 9 Products:")
print(df_experimental.head())

print("\nProduct Template:")
print(df_template.head())
# Display the first few rows of each DataFrame
print("Experimental Sample 9 Products:")
print(df_experimental.head())

print("\nProduct Template:")
print(df_template.head())
# Check for missing values in both DataFrames
print("Missing values in Experimental Sample 9 Products:")
print(df_experimental.isnull().sum())

print("\nMissing values in Product Template:")
print(df_template.isnull().sum())
# Display summary statistics for both DataFrames
print("Summary statistics for Experimental Sample 9 Products:")
print(df_experimental.describe())

print("\nSummary statistics for Product Template:")
print(df_template.describe())
# Assuming there is a common column 'ProductID' to merge on
common_columns = set(df_experimental.columns).intersection(set(df_template.columns))
if 'ProductID' in common_columns:
    merged_df = pd.merge(df_experimental, df_template, on='ProductID', how='inner')
    print("Merged DataFrame:")
    print(merged_df.head())
else:
    print("No common 'ProductID' column found for merging.")
# Example: Group by a categorical column and calculate the mean of numerical columns
if 'Category' in df_experimental.columns:
    grouped_df = df_experimental.groupby('Category').mean()
    print("Grouped DataFrame by Category:")
    print(grouped_df)
else:
    print("No 'Category' column found in the experimental data for grouping.")
# Out:
# Experimental Sample 9 Products:
#        Type            SKU            Name  Published  Is featured?  \
# 0  variable  woo-vneck-tee  V-Neck T-Shirt          1             1
# 1  variable     woo-hoodie          Hoodie          1             0
# 2    simple     woo-tshirt         T-Shirt          1             0
# 3    simple     woo-beanie          Beanie          1             0
# 4    simple       woo-belt            Belt          1             0
#
#   Visibility in catalog            Short description  \
# 0               visible  This is a variable product.
# 1               visible  This is a variable product.
# 2               visible    This is a simple product.
# 3               visible    This is a simple product.
# 4               visible    This is a simple product.
#
#                                          Description  Date sale price starts  \
# 0  Pellentesque habitant morbi tristique senectus...                     NaN
# ...

# %%
# Data Analysis with Pandas

## Step 1: Import Libraries

import pandas as pd
# Load the CSV files
df_experimental = pd.read_csv(r'C:\xampp\htdocs\project_excel_postgresql\products_one.csv')
df_template = pd.read_csv(r'C:\xampp\htdocs\project_excel_postgresql\product_two.csv')

# %%
# Display the first few rows of each DataFrame
print("Experimental Sample 9 Products:")
print(df_experimental.head())

print("\nProduct Template:")
print(df_template.head())
# Out:
# Experimental Sample 9 Products:
#        Type            SKU            Name  Published  Is featured?  \
# 0  variable  woo-vneck-tee  V-Neck T-Shirt          1             1
# 1  variable     woo-hoodie          Hoodie          1             0
# 2    simple     woo-tshirt         T-Shirt          1             0
# 3    simple     woo-beanie          Beanie          1             0
# 4    simple       woo-belt            Belt          1             0
#
#   Visibility in catalog            Short description  \
# 0               visible  This is a variable product.
# 1               visible  This is a variable product.
# 2               visible    This is a simple product.
# 3               visible    This is a simple product.
# 4               visible    This is a simple product.
#
#                                          Description  Date sale price starts  \
# 0  Pellentesque habitant morbi tristique senectus...                     NaN
# ...

# %%
# Check for missing values in both DataFrames
print("Missing values in Experimental Sample 9 Products:")
print(df_experimental.isnull().sum())

print("\nMissing values in Product Template:")
print(df_template.isnull().sum())
# Out:
# Missing values in Experimental Sample 9 Products:
# Type                        0
# SKU                         0
# Name                        0
# Published                   0
# Is featured?                0
# Visibility in catalog       0
# Short description           0
# Description                 0
# Date sale price starts      9
# Date sale price ends        9
# Tax status                  0
# Tax class                   9
# In stock?                   0
# Stock                       9
# Backorders allowed?         0
# Sold individually?          0
# Weight (lbs)                1
# Length (in)                 1
# Width (in)                  1
# Height (in)                 1
# Allow customer reviews?     0
# Purchase note               9
# Sale price                  6
# Regular price               3
# Categories                  0
# Tags                        9
# Shipping class              9
# Images                      0
# Download limit              9
# ...

# %%
# Display summary statistics for both DataFrames
print("Summary statistics for Experimental Sample 9 Products:")
print(df_experimental.describe())

print("\nSummary statistics for Product Template:")
print(df_template.describe())
# Out:
# Summary statistics for Experimental Sample 9 Products:
#        Published  Is featured?  Date sale price starts  Date sale price ends  \
# count        9.0      9.000000                     0.0                   0.0
# mean         1.0      0.333333                     NaN                   NaN
# std          0.0      0.500000                     NaN                   NaN
# min          1.0      0.000000                     NaN                   NaN
# 25%          1.0      0.000000                     NaN                   NaN
# 50%          1.0      0.000000                     NaN                   NaN
# 75%          1.0      1.000000                     NaN                   NaN
# max          1.0      1.000000                     NaN                   NaN
#
#        Tax class  In stock?  Stock  Backorders allowed?  Sold individually?  \
# count        0.0        9.0    0.0                  9.0                 9.0
# ...

# %%
# Assuming there is a common column 'ProductID' to merge on
common_columns = set(df_experimental.columns).intersection(set(df_template.columns))
if 'ProductID' in common_columns:
    merged_df = pd.merge(df_experimental, df_template, on='ProductID', how='inner')
    print("Merged DataFrame:")
    print(merged_df.head())
else:
    print("No common 'ProductID' column found for merging.")
# Out:
# No common 'ProductID' column found for merging.

# %%
# Example: Group by a categorical column and calculate the mean of numerical columns
if 'Category' in df_experimental.columns:
    grouped_df = df_experimental.groupby('Category').mean()
    print("Grouped DataFrame by Category:")
    print(grouped_df)
else:
    print("No 'Category' column found in the experimental data for grouping.")
# Out:
# No 'Category' column found in the experimental data for grouping.
